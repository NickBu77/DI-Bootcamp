# %%
import pandas as pd

csv_path = r'/content/sample_data/california_housing_train.csv'

cali_pd = pd.read_csv(csv_path)

cali_df = pd.DataFrame(cali_pd)

# %%
cali_df.iloc[0:3]
cali_df.iloc[-3:]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
cali_df.head(3)
cali_df.tail(3)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
head = cali_df.head(7).tail(1)
head
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6    -114.58     33.61                25.0       2907.0           680.0
#
#    population  households  median_income  median_house_value
# 6      1841.0       633.0         2.6768             82400.0

# %%
cali_df.iloc[7]
# Out:
# longitude              -114.5900
# latitude                 34.8300
# housing_median_age       41.0000
# total_rooms             812.0000
# total_bedrooms          168.0000
# population              375.0000
# households              158.0000
# median_income             1.7083
# median_house_value    48500.0000
# Name: 7, dtype: float64

# %%
cali_df['ethnicity'] = 'Unknown'
# cali_df.drop('total_bedrooms', axis=1, inplace=True) #can be inferred from total rooms
cali_df_renamed = cali_df.rename(columns={'housing_median_age':'median_age_in_house'})
cali_df_renamed
# Out:
#        longitude  latitude  median_age_in_house  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                 15.0       5612.0          1283.0
# 1        -114.47     34.40                 19.0       7650.0          1901.0
# 2        -114.56     33.69                 17.0        720.0           174.0
# 3        -114.57     33.64                 14.0       1501.0           337.0
# 4        -114.57     33.57                 20.0       1454.0           326.0
# ...          ...       ...                  ...          ...             ...
# 16995    -124.26     40.58                 52.0       2217.0           394.0
# 16996    -124.27     40.69                 36.0       2349.0           528.0
# 16997    -124.30     41.84                 17.0       2677.0           531.0
# 16998    -124.30     41.80                 19.0       2672.0           552.0
# 16999    -124.35     40.54                 52.0       1820.0           300.0
#
# ...

# %%
mean_rooms = cali_df_renamed['total_rooms'].mean()
mean_rooms
# Out:
# 2643.664411764706

# %%
max_pop = cali_df_renamed['population'].max()
max_pop
# Out:
# 35682.0

# %%
over300k = cali_df_renamed[cali_df_renamed['median_house_value'] > 300000]
over300k
over300k.count()
over300k['total_rooms'].sum()
# Out:
# 9644592.0
