# %% [markdown]
# Tasks:
# Data Import and Cleaning:
#
# Import the dataset using Pandas.
# Identify missing values and handle them appropriately.
# Use NumPy to convert relevant columns to numerical types if necessary.
# Exploratory Data Analysis:
#
# Utilize Pandas to summarize key statistics (mean, median, standard deviation) for numerical columns.
# Explore the distribution of power plants by country and fuel type.
# Statistical Analysis:
#
# Perform a statistical analysis of power output by fuel type using NumPy’s statistical functions.
# Use hypothesis testing to determine if the mean power output differs significantly between different fuel types.
# Time Series Analysis:
#
# If the dataset includes time-related data (like year of establishment), use NumPy to analyze trends over time.
# Explore how the mix of fuel types for power generation has evolved over the years.
# Advanced Visualization:
#
# Create visualizations using Matplotlib and Seaborn to illustrate your findings.
# Consider plotting the geographical distribution of power plants using latitude and longitude data, if available.
# Matrix Operations in Real-World Context:
#
# Demonstrate matrix operations by analyzing relationships between different attributes (e.g., fuel type, capacity, and geographic location).
# Discuss the relevance of eigenvectors and eigenvalues in this context.
# Integrating NumPy with Pandas and Matplotlib:
#
# Show how NumPy can be used to enhance data manipulation in Pandas and data visualization in Matplotlib.
# Provide examples, such as using NumPy arrays for complex filtering in Pandas or for creating sophisticated plots in Matplotlib.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

path = '/content/global_power_plant_database.csv'

data = pd.read_csv(path)
df = pd.DataFrame(data)
df
# Out:
# <ipython-input-244-cb0098af38ba>:7: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(path)
#       country country_long                                               name  \
# 0         AFG  Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 1         AFG  Afghanistan                                       Kandahar DOG
# 2         AFG  Afghanistan                                       Kandahar JOL
# 3         AFG  Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 4         AFG  Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# ...       ...          ...                                                ...
# 34931     ZMB       Zambia                                              Ndola
# 34932     ZMB       Zambia                                              Nkana
# 34933     ZMB       Zambia                                     Victoria Falls
# ...

# %%
df[df.isna().any(axis=1)]
# Out:
#       country country_long                                               name  \
# 0         AFG  Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 1         AFG  Afghanistan                                       Kandahar DOG
# 2         AFG  Afghanistan                                       Kandahar JOL
# 3         AFG  Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 4         AFG  Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# ...       ...          ...                                                ...
# 34931     ZMB       Zambia                                              Ndola
# 34932     ZMB       Zambia                                              Nkana
# 34933     ZMB       Zambia                                     Victoria Falls
# 34934     ZWE     Zimbabwe                   Hwange Coal Power Plant Zimbabwe
# 34935     ZWE     Zimbabwe  Kariba Dam South Hydroelectric Power Station Z...
#
# ...

# %%
df.mean()
# Out:
# <ipython-input-245-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# capacity_mw                       163.355148
# latitude                           32.816637
# longitude                          -6.972803
# commissioning_year               1997.414823
# year_of_capacity_data            2018.218849
# generation_gwh_2013               592.696107
# generation_gwh_2014               656.863891
# generation_gwh_2015               762.368840
# generation_gwh_2016               693.149763
# generation_gwh_2017               661.834161
# generation_gwh_2018               517.320785
# generation_gwh_2019               423.922436
# estimated_generation_gwh_2013     239.112221
# estimated_generation_gwh_2014     242.431122
# ...

# %%
df.std()
# Out:
# <ipython-input-246-ce97bb7eaef8>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# capacity_mw                       489.636072
# latitude                           22.638603
# longitude                          78.405850
# commissioning_year                 23.397835
# year_of_capacity_data               1.606428
# generation_gwh_2013              2174.833482
# generation_gwh_2014              2231.464288
# generation_gwh_2015              2533.459828
# generation_gwh_2016              2404.516759
# generation_gwh_2017              2369.296957
# generation_gwh_2018              1975.302686
# generation_gwh_2019              1698.506485
# estimated_generation_gwh_2013    1191.258172
# estimated_generation_gwh_2014    1285.798297
# ...

# %%
df.median()
# Out:
# <ipython-input-247-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# capacity_mw                        16.745000
# latitude                           39.727750
# longitude                          -2.127100
# commissioning_year               2007.000000
# year_of_capacity_data            2019.000000
# generation_gwh_2013                23.426000
# generation_gwh_2014                23.608500
# generation_gwh_2015                26.142000
# generation_gwh_2016                22.462389
# generation_gwh_2017                17.876500
# generation_gwh_2018                12.530000
# generation_gwh_2019                11.530000
# estimated_generation_gwh_2013      27.620000
# estimated_generation_gwh_2014      28.250000
# ...

# %%
df.var()
# Out:
# <ipython-input-248-28ded241fd7c>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# capacity_mw                      2.397435e+05
# latitude                         5.125063e+02
# longitude                        6.147477e+03
# commissioning_year               5.474587e+02
# year_of_capacity_data            2.580612e+00
# generation_gwh_2013              4.729901e+06
# generation_gwh_2014              4.979433e+06
# generation_gwh_2015              6.418419e+06
# generation_gwh_2016              5.781701e+06
# generation_gwh_2017              5.613568e+06
# generation_gwh_2018              3.901821e+06
# generation_gwh_2019              2.884924e+06
# estimated_generation_gwh_2013    1.419096e+06
# estimated_generation_gwh_2014    1.653277e+06
# ...

# %% [markdown]
# Perform a statistical analysis of power output by fuel type using NumPy’s statistical functions. Use hypothesis testing to determine if the mean power output differs significantly between different fuel types.

# %%
avg = df.groupby('primary_fuel')['generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
       'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018',
       'generation_gwh_2019'].mean()

avg
# Out:
# <ipython-input-250-ec4e5f041da0>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   avg = df.groupby('primary_fuel')['generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#                 generation_gwh_2013  generation_gwh_2014  generation_gwh_2015  \
# primary_fuel
# Biomass                  176.264669           161.055230           206.178372
# Coal                    4066.013021          4306.421815          4105.549270
# Cogeneration             128.354154           109.370187           106.233357
# Gas                      678.934632           697.049560           779.075021
# Geothermal               261.721122           264.049305           267.354919
# Hydro                    257.631846           257.848783           264.805663
# Nuclear                13333.621024         12467.254956         13519.802189
# ...

# %%
avg['fuel_sum'] = avg.mean(axis=1)
wnt = avg.index=='Wave and Tidal'
avg = avg[~wnt]
# Out:
# <ipython-input-263-a34609d1a273>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   avg['fuel_sum'] = avg.mean(axis=1)

# %%
avg
# Out:
#               generation_gwh_2013  generation_gwh_2014  generation_gwh_2015  \
# primary_fuel
# Biomass                176.264669           161.055230           206.178372
# Coal                  4066.013021          4306.421815          4105.549270
# Cogeneration           128.354154           109.370187           106.233357
# Gas                    678.934632           697.049560           779.075021
# Geothermal             261.721122           264.049305           267.354919
# Hydro                  257.631846           257.848783           264.805663
# Nuclear              13333.621024         12467.254956         13519.802189
# Oil                     30.112928            33.559534            49.856727
# Other                   95.567432            79.413439           162.546092
# Petcoke                944.043346           754.365254           692.195090
# Solar                   13.954062            18.128063            21.622091
# ...

# %%
maxvalue= avg['fuel_sum'].max()
maxindex = avg['fuel_sum'].idxmax()
minvalue= avg['fuel_sum'].min()
minindex = avg['fuel_sum'].idxmin()

print(f'The max is {maxvalue}, by energy source {maxindex}')

print(f'The min is {minvalue}, by energy source {minindex}')

print('This is a huge discrepancy. Solar is highly inneficient relative to nuclear.')
# Out:
# The max is 92916.56404934301, by energy source Nuclear
# The min is 144.6970798132812, by energy source Solar
# This is a huge discrepancy. Solar is highly inneficient relative to nuclear.

# %% [markdown]
# Explore the distribution of power plants by country and fuel type.

# %%
fuel_group = df.groupby(['country','primary_fuel'])['primary_fuel'].count()
group_df = pd.DataFrame(fuel_group)
group_df = group_df.rename(columns={'primary_fuel': 'count'})
group_df
# Out:
#                       count
# country primary_fuel
# AFG     Gas               1
#         Hydro             6
#         Solar             2
# AGO     Gas               3
#         Hydro             5
# ...                     ...
# ZMB     Hydro             5
#         Oil               7
#         Solar             1
# ZWE     Coal              1
#         Hydro             1
#
# [698 rows x 1 columns]

# %%
group_df = group_df.reset_index()

# %%
group_df
# Out:
#     country primary_fuel  count
# 0       AFG          Gas      1
# 1       AFG        Hydro      6
# 2       AFG        Solar      2
# 3       AGO          Gas      3
# 4       AGO        Hydro      5
# ..      ...          ...    ...
# 693     ZMB        Hydro      5
# 694     ZMB          Oil      7
# 695     ZMB        Solar      1
# 696     ZWE         Coal      1
# 697     ZWE        Hydro      1
#
# [698 rows x 3 columns]

# %%
country_selection = group_df['country'].sample(n=10)
country_list = list(country_selection)
reduced_df = group_df[group_df['country'].isin(country_list)]
reduced_df
# Out:
#     country    primary_fuel  count
# 10      ARG            Coal      9
# 11      ARG             Gas     57
# 12      ARG           Hydro     50
# 13      ARG         Nuclear      3
# 14      ARG             Oil     96
# 15      ARG           Other      2
# 16      ARG           Solar      7
# 17      ARG            Wind     12
# 34      AZE             Gas      8
# 35      AZE           Hydro      5
# 36      AZE             Oil      1
# 58      BGR            Coal     11
# 59      BGR           Hydro      7
# 60      BGR         Nuclear      1
# 61      BGR           Solar     23
# 62      BGR            Wind      1
# 70      BOL             Gas      9
# 71      BOL           Hydro     14
# 72      BOL           Solar      3
# 88      CAN         Biomass    111
# 89      CAN            Coal     15
# 90      CAN             Gas     75
# 91      CAN           Hydro    556
# 92      CAN         Nuclear      6
# 93      CAN             Oil      9
# 94      CAN           Other      2
# ...

# %% [markdown]
# **For Charlotte:** Not sure how to map by both country and primary fuel on same graph.

# %%
plt.bar(reduced_df['country'],reduced_df['count'])
plt.bar(reduced_df['primary_fuel'],reduced_df['count'])
# Out:
# <BarContainer object of 49 artists>

# %% [markdown]
# If the dataset includes time-related data (like year of establishment), use NumPy to analyze trends over time. Explore how the mix of fuel types for power generation has evolved over the years. Advanced Visualization:

# %%
firstyear = df.groupby(['primary_fuel','commissioning_year'])['primary_fuel'].count()

# %%
df = pd.DataFrame(firstyear)
df.rename(columns={'primary_fuel':'count'}, inplace=True)
new_df = df.reset_index()

# %%
sns.lineplot(x='commissioning_year', y='count',hue='primary_fuel',data=new_df, palette='bright')

#sns.lineplot(data=new_df[new_df['primary_fuel'] == 'Nuclear'], x='commissioning_year', y='count', color='red')
# Out:
# <Axes: xlabel='commissioning_year', ylabel='count'>

# %%
sns.set_palette(['brown'])
sns.lineplot(x='commissioning_year', y='count',hue='primary_fuel',data=new_df[new_df['primary_fuel']=='Hydro'])
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %%
sns.set_palette(['blue'])
sns.lineplot(x='commissioning_year', y='count',hue='primary_fuel',data=new_df[new_df['primary_fuel']=='Solar'])
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %%
sns.set_palette(['red'])
sns.lineplot(x='commissioning_year', y='count',hue='primary_fuel',data=new_df[new_df['primary_fuel']=='Gas'])
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %% [markdown]
# One conclusion we can reach is that hydro has been in consistent use from 1900 to 2020. However, since 2010 we've seen a big increase in Solar plants. There was also a spike in gas plants in 2000 and it is among the highest number of new starts since then

# %% [markdown]
# Create visualizations using Matplotlib and Seaborn to illustrate your findings. Consider plotting the geographical distribution of power plants using latitude and longitude data, if available.

# %%
plt.scatter(df['longitude'], df['latitude'], marker='o', s=1)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Geographical Distribution of Power Plants')
plt.show()

# %% [markdown]
# It appears that Europe  and the US, along with east Asia(looks like south india and China) have the highest density of power plants.

# %% [markdown]
# Demonstrate matrix operations by analyzing relationships between different attributes (e.g., fuel type, capacity, and geographic location). Discuss the relevance of eigenvectors and eigenvalues in this context. Integrating NumPy with Pandas and Matplotlib:
#
# Show how NumPy can be used to enhance data manipulation in Pandas and data visualization in Matplotlib. Provide examples, such as using NumPy arrays for complex filtering in Pandas or for creating sophisticated plots in Matplotlib.

# %% [markdown]
# For Charlotte: ot sure how to practically apply matrix applications to this.
