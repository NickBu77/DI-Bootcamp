# %% [markdown]
# Challenge Description:
# Scenario: You are a data analyst working with a dataset of global weather. Your task is to analyze temperature trends and visualize the results.

# %% [markdown]
# Instructions
# 1. Data Preparation:
#
#
#
# Hint 1: Use np.random.uniform(low, high, size) to generate the temperature data.
# Hint 2: Create a DataFrame using pd.DataFrame(data, index, columns) with appropriate index and columns.
#
# Use NumPy to generate a synthetic dataset representing average monthly temperatures (in degrees Celsius) for 12 months across 10 different cities. The temperatures should range from -5 to 35 degrees.
#
# Convert this NumPy array into a Pandas DataFrame, adding city names as index and months as columns.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.DataFrame({'1': [37,36,23], '2': [37,36,23], '3':[37,36,23]})

df
# Out:
#     1   2   3
# 0  37  37  37
# 1  36  36  36
# 2  23  23  23

# %%
square_dict = {date: np.random.uniform(-5, 36, 10)  for date in pd.date_range(start='2023-01-01', end='2023-12-31', freq='M')}
cities = ['NYC','LA','San Fran','Boston','Charlotte','Miami','Detroit','Chicago','Baltimore','San Diego']
temps_df = pd.DataFrame(square_dict, index=cities)

# %% [markdown]
# 2. Data Analysis:
#
#
#
# Hint 1: Calculate the annual average temperature using DataFrame.mean(axis).
# Hint 2: Find the city with the highest and lowest average temperature using idxmax() and idxmin() methods.
#
# Calculate the annual average temperature for each city.
#
# Identify the city with the highest and lowest average temperature for the year.

# %%
averages = temps_df.mean(axis=1)
averages
# Out:
# NYC          16.601437
# LA           14.889308
# San Fran     10.453489
# Boston       16.889929
# Charlotte    16.671000
# Miami        14.776320
# Detroit      16.333434
# Chicago      16.581556
# Baltimore    17.766229
# San Diego    11.082845
# dtype: float64

# %%
# method 1 that I came up with
print(f'The min annual temp, {averages.min()}, is in {averages.index.min()} \n The max annual temp, {averages.max()}, is in {averages.index.max()}')
# Out:
# The min annual temp, 10.45348922988636, is in Baltimore
#  The max annual temp, 17.76622891196223, is in San Fran

# %%
# method 2 that came from the hint on the platform
print(f'The min annual temp, {averages.min()}, is in {averages.idxmin()} \n The max annual temp, {averages.max()}, is in {averages.idxmax()}')
# Out:
# The min annual temp, 10.45348922988636, is in San Fran
#  The max annual temp, 17.76622891196223, is in Baltimore

# %% [markdown]
# 3. Data Visualization:
#
#
#
# Hint 1: Use plt.plot() for each city’s temperature trends. Adjust the linewidth and linestyle for the highlighted cities.
# Hint 2: Use plt.title(), plt.xlabel(), plt.ylabel(), and plt.legend() to add details to your plot.
#
# Use Matplotlib to create a line plot showing the monthly temperature trends for each city.
#
# Highlight the city with the highest and lowest average annual temperature in a different color or line style.

# %%
temps_df
# Out:
#            2023-01-31  2023-02-28  2023-03-31  2023-04-30  2023-05-31  \
# NYC         25.604922   -0.236018   29.248846   14.476813   11.665866
# LA          18.801992    2.193137   17.096861   34.452884   17.928609
# San Fran    26.430230    8.644197   -1.029577    3.341081    1.191101
# Boston       0.703385   31.432111   29.411897   27.656238   24.581738
# Charlotte    6.061794   27.054004    5.609040    0.791385   35.610499
# Miami        5.778303   11.440939   18.680983    5.690393    6.786789
# Detroit      7.076427   30.641885   27.644512   30.364839   -0.294151
# Chicago     13.840169   15.128384   20.021074   -3.789139   15.817717
# Baltimore   28.211912   -3.908484   23.352743   27.209725   26.299808
# San Diego    2.887359    7.447995   -2.326187    3.576496    7.088457
#
#            2023-06-30  2023-07-31  2023-08-31  2023-09-30  2023-10-31  \
# NYC         20.833172   14.718453   31.808532   -4.169109   22.738736
# LA           8.559814   15.127580   -3.766834   28.679346   33.992826
# San Fran    -2.785989   -2.840706   17.468254   29.159699   35.511704
# Boston      13.125899    4.145589    1.207514   24.904765   12.686246
# Charlotte   18.793063   19.013316   26.536167   34.267881   12.631015
# Miami        1.495825   22.915626   -3.812352   33.954063   17.665927
# Detroit     25.898639   16.472603   16.090692   31.694443    7.289738
# Chicago     32.387966   26.906534   17.566406   26.885173    8.843714
# Baltimore   12.051779    2.095094    1.609543   34.051924   -2.900873
# San Diego   32.617427   32.028203    2.820535    0.188459   28.266821
#
#            2023-11-30  2023-12-31
# NYC         33.611613   -1.084578
# LA          -0.811625    6.417101
# San Fran     7.461867    2.890010
# Boston      35.145219   -2.321453
# Charlotte   16.987944   -3.304105
# Miami       28.178601   28.540738
# Detroit      3.884955   -0.763373
# Chicago      8.947215   16.423457
# Baltimore   34.475857   30.645718
# San Diego   10.106719    8.291856

# %%
temps_df_transposed = temps_df.transpose()

ax = temps_df_transposed.plot()
plt.title('Cities temp by month')
plt.xlabel('Month')
plt.ylabel('Temp')

for line in ax.lines:
    if 'San Fran' in line.get_label():
        line.set_linestyle('-.')
    elif 'Baltimore' in line.get_label():
        line.set_linewidth('3')

plt.show()
